# %% [markdown]
# # Signal types

# %%
from demos.plot_test1 import plot_test1
plot_test1()
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-61a49c00590e>", line 2, in <module>
#     from demos.plot_test1 import plot_test1
#
#   File "/home/mph/text/16/lectures/enmt301/dsp-notebooks/intro/demos/plot_test1.py", line 8
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax

# %%
from demos.plot_test2 import plot_test2
plot_test2()
# Out:
# interactive(children=(IntSlider(value=1000, description='n', max=2000, min=1000), Output()), _dom_classes=('wi…
